# %% [markdown]
# # Super gentle introduction to Machine Learning for APSE (ENG5337)
#
# **Forword**
#
# You are reading this Jupyter Notebook because the assignment \#2 tells you to do so 😏.
#
# In order to understand the assignment \#2, we shall explore the first few concepts in Machine Learning and how to implement them in Python. Then, we will apply this knowledge and skills in Python to write a "micro-library" for two widely used supervised learning frameworks
# - **Linear Regression.**
#     **Linear Regression** is used to make prediction on the continous spectrum of data points.
#
#     **Examples**
#
#     - Predict the house price of a given flat given its features such as total living area, number of bedrooms, distance to the city center, distance to schools, distance to public transporation stations, $\ldots$
#     - Predict the age of a person by using their recent photos.
#     - Predict the price of a bottle of wine given its information about the wine: number of years, location, type of grapdes, $\ldots$
#
#     **Linear regression** can be easily extended to **Polynomial Regression** to enhance its power and widen its capability in various complex applications.
# - **Logistic Regression**
#     **Logistic Regression** is used to make classify data points into finite number of categories, such as $0, 1, 2, \ldots, K$.
#
#     **Examples**
#     - Given an image of one digit written by hand, predict what number it represents. The number is just
#     - Given a
#
# **Supervised Learning**
#
# Both of these regression methods are classified as **supervised learning** methods in which we have the input data given by $\mathbf{x}^{(i)} = (x_1^{(i)}, x_2^{(i)}, \ldots, x_n^{(i)})$ and output data given by $y^{(i)}$ for $i = 1, \ldots, m$, where $m$ is the number of samples. So, the database $\mathcal{D}$ must have both inputs $\{\mathbf{x}^{(i)}\}_{i=1}^{m}$ and outputs $\{y^{(i)}\}_{i=1}^{m}$:
#
# $$
# \mathcal{D} = \Big\{ (\mathbf{x}^{(1)}, y^{(1)}), (\mathbf{x}^{(2)}, y^{(2)}), \ldots, (\mathbf{x}^{(m)}, y^{(m)}) \Big\}
# $$
